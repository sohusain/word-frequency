# %%
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import requests
import urllib
from bs4 import BeautifulSoup
import nltk
from collections import Counter

# %% [markdown]
# ## Objective
# Get a list of the most frequent words used in Middlemarch by George Eliot

# %% [markdown]
# ### Get Novel
# We can use this site: https://www.gutenberg.org/ebooks/145

# %%
link = "https://www.gutenberg.org/cache/epub/145/pg145.txt"

f = requests.get(link)
print(f.text)
# Out:
# ﻿The Project Gutenberg eBook of Middlemarch
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: Middlemarch
#
#
# Author: George Eliot
#
# Release date: July 1, 1994 [eBook #145]
#                 Most recently updated: May 1, 2023
#
# Language: English
#
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK MIDDLEMARCH ***
#
#
#
# cover
#
#
#
#
# Middlemarch
#
# George Eliot
#
# New York and Boston
# H. M. Caldwell Company Publishers
#
# To my dear Husband, George Henry Lewes,
# in this nineteenth year of our blessed union.
#
#
# Contents
#
#  PRELUDE.
#
#  BOOK I. MISS BROOKE.
# ...
